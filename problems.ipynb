# %% [markdown]
# # Computer Infrastructure Assessment 2025 - Problems

# %% [markdown]
# ## Problem 1: Data from yfinance

# %%
# Step 1: Import necessary libraries
import yfinance as yf # yfinance lets us download stock data from Yahoo Finance
import pandas as pd # # pandas is for data manipulation; main object is DataFrame (a table-like structure)
from datetime import datetime # # datetime allows us to work with dates and times and will allow us to timestamp files
import os  # os allows us to interact with the operating system (e.g., folders, file paths)

# Define the function to download stock data
def getdata()
"""
    Downloads hourly stock data for the last 5 days for FAANG stocks
    and saves it as a CSV file in the 'data' folder with timestamped filename.
"""
  # List of FAANG stock tickers
   faang_stocks = ['META', 'APPL', 'AMZN', 'NFLX', 'GOOG']
  # 'faang_stocks' is a Python list object, which is an ordered collection of items
  # I will loop through this list to fetch data for each stock
  
  # Download data using yfinance
  # yf.download() returns a pandas DataFrame 
  # 'period="5d"' → last 5 days, 'interval="1h"' → hourly data
# Out:
#   Cell In[4], line 8
#     def getdata()
#                  ^
# SyntaxError: expected ':'
